# %% [markdown]
# # LinkedIn Webscraper

# %% [markdown]
# ## Part I
# Getting Data from LinkedIn

# %%
from bs4 import BeautifulSoup
from datetime import datetime 
import pandas
import requests
from sqlalchemy import create_engine

# %%
positions = [
    'SAP-Entwickler/SAP-Berater',
    'IT-Projektmanager',
    'Softwareentwickler',
    'Business Intelligence Analyst',
    'IT-Controller',
    'IT-Berater',
    'Produktmanager',
    'App-Entwickler',
    'Anwendungsentwickler',
    'Datenbankspezialist',
    'ERP Manager'
]

joblistings = []

for position in positions:
    url = f'https://de.linkedin.com/jobs/{position}-stellen?position=1&pageNum=0'
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    posts = soup.find_all('div', class_ = 'base-card')
    for post in posts:
        title = post.find('h3', class_ = 'base-search-card__title').text.strip()
        company = post.find('h4', class_ = 'base-search-card__subtitle').text.strip()
        try:
            location = post.find('span', class_ = 'job-search-card__location').text.strip()
        except:
            location = 'unknown'
        link = post.find('a', class_ = 'base-card__full-link').get('href')
        job = {
            'title': title,
            'company': company,
            'location': location,
            'link': link,
            'Date': datetime.now().date(),
            'Timestamp': datetime.now().time()
        }
        joblistings.append(job)

df_job = pandas.DataFrame(joblistings)
df_job
# Out:
#                                                  title  \
# 0                            SAP Developer/Consultant*
# 1          SAP Inhouse Consultant / Entwickler (m|w|d)
# 2     (Senior) Consultant und Architekt SAP * (Remote)
# 3                 IT Solution Architect SAP CO (w/m/d)
# 4    Junior SAP Consultant ABAP - IT Beratung / Sof...
# ..                                                 ...
# 256                           ERP Project Manager DACH
# 257                       European ERP Project Manager
# 258                     ERP/IT Project Manager (m/f/d)
# 259            ERP Application Support Manager (m/f/d)
# 260            ERP Application Support Manager (m/f/d)
#
#                                              company        location  \
# 0                                       Xaption GmbH         Steinen
# 1                                               ADAC         München
# 2                                 Evora IT Solutions        Walldorf
# 3                                              STIHL        Fellbach
# 4                                    amiconsult GmbH       Karlsruhe
# ..                                               ...             ...
# 256                         Cloudmaven ERP Solutions         München
# 257  Cognitive Group | Part of the Focus Cloud Group     Deutschland
# 258      Meyer Quick Service Logistics GmbH & Co. KG  Friedrichsdorf
# 259                           ebu Umformtechnik GmbH        Bayreuth
# 260                                   FUCHS Bau GmbH       Hainichen
#
#                                                   link        Date  \
# 0    https://de.linkedin.com/jobs/view/sap-develope...  2023-02-21
# 1    https://de.linkedin.com/jobs/view/sap-inhouse-...  2023-02-21
# 2    https://de.linkedin.com/jobs/view/senior-consu...  2023-02-21
# 3    https://de.linkedin.com/jobs/view/it-solution-...  2023-02-21
# 4    https://de.linkedin.com/jobs/view/junior-sap-c...  2023-02-21
# ..                                                 ...         ...
# 256  https://de.linkedin.com/jobs/view/erp-project-...  2023-02-21
# 257  https://de.linkedin.com/jobs/view/european-erp...  2023-02-21
# 258  https://de.linkedin.com/jobs/view/erp-it-proje...  2023-02-21
# 259  https://de.linkedin.com/jobs/view/erp-applicat...  2023-02-21
# 260  https://de.linkedin.com/jobs/view/erp-applicat...  2023-02-21
#
#            Timestamp
# 0    13:45:45.025346
# 1    13:45:45.025346
# 2    13:45:45.025346
# 3    13:45:45.025346
# 4    13:45:45.025346
# ..               ...
# 256  13:45:58.107417
# 257  13:45:58.107417
# 258  13:45:58.107417
# 259  13:45:58.107417
# 260  13:45:58.107417
#
# [261 rows x 6 columns]

# %% [markdown]
# ## Part II
#
# Saving Data to a Database

# %%
connection = create_engine('mysql+pymysql://root:@localhost/businessintelligence')
df_job.to_sql('job', con=connection, index=False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\DE117339\Documents\BI-Dashboard\linkedIn.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DE117339/Documents/BI-Dashboard/linkedIn.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> connection = create_engine('mysql+pymysql://root:@localhost/businessintelligence')
#       <a href='vscode-notebook-cell:/c%3A/Users/DE117339/Documents/BI-Dashboard/linkedIn.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> df_job.to_sql('job', con=connection, index=False, if_exists='append')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\util\deprecations.py:375, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     368     if m in kwargs:
#     369         _warn_with_version(
#     370             messages[m],
#     371             versions[m],
#     372             version_warnings[m],
#     373             stacklevel=3,
#     374         )
# --> 375 return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\create.py:548, in create_engine(url, **kwargs)
#     546         if k in kwargs:
#     547             dbapi_args[k] = pop_kwarg(k)
# --> 548     dbapi = dialect_cls.dbapi(**dbapi_args)
#     550 dialect_args["dbapi"] = dbapi
#     552 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\dialects\mysql\pymysql.py:68, in MySQLDialect_pymysql.dbapi(cls)
#      66 @classmethod
#      67 def dbapi(cls):
# ---> 68     return __import__("pymysql")
#
# ModuleNotFoundError: No module named 'pymysql'
